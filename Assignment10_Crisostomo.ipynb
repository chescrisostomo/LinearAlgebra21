# %% [markdown]
# <a href="https://colab.research.google.com/github/chescrisostomo/LinearAlgebra21/blob/main/Assignment10_Crisostomo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Algebra for ECE
#
# ## Laboratory 10: Linear Combination and Vector Spaces
#
# Now that you have a findamental knowledge about linear combination, we'll try to visualize it using scientifics programming.

# %% [markdown]
# #### Objectives:
#
# At the end of this activity you will be able to:
# 1. Be familiar with representing linear combinations in the 2-dimensional plane.
# 2. Visualize spans using vector fields in Python.
# 3. Perform vector fields operations using scientific programming.

# %% [markdown]
# ## Discussion

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Linear Combiantion
#
# It is said that a linear combination of linear scaling and adtion of a vector its bases/ components
#
# We will try to visualize the vectors and their linear combinatios by plotting a sample of real number values for the scalars for the vectors. let's first try the vectors below:

# %% [markdown]
# $$X = \begin{bmatrix} 2\\5 \\\end{bmatrix} , Y = \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
vectX = np.array([2,5])
vectY = np.array([7,9])
vectY
# Out:
# array([7, 9])

# %% [markdown]
# #### Span of single vectors
#
# As discussed in the lecture, the span of individual vectors can be represented by a line span. Let's take vector $X$ as an example.

# %% [markdown]
# $$X = c\cdot \begin{bmatrix} 2\\5 \\\end{bmatrix} $$

# %%
c = np.arange(-10,10,0.125)

plt.scatter(c*vectX[0],c*vectX[1])

plt.xlim(-10,10)
plt.ylim(-10,10)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$Y = c\cdot \begin{bmatrix} 7\\9 \\\end{bmatrix} $$

# %%
c = np.arange(-15,15,0.5)

plt.scatter(c*vectY[0],c*vectY[1])

plt.xlim(-20,20)
plt.ylim(-20,20)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# #### Span of a linear combination of vectors
#
# So what if we are to plot the span of a linear combination of vectors? We can visualize as a plane on the 2-dimensional coordinate system. Let's take the span of the linear combination below#

# %% [markdown]
# $$S = \begin{Bmatrix} c_1 \cdot\begin{bmatrix} 1\\0 \\\end{bmatrix},
# c_2 \cdot \begin{bmatrix} 1\\-1 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectA = np.array([1,0])
vectB= np.array([1,-1])

R = np.arange (-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectA + vectB
spanRx = c1*vectA[0] + c2*vectB[0]
spanRy = c1*vectA[1] + c2*vectB[1]
##plt.scatter (R*vectA[0], R*vectA[1])
##plt.scatter (R*vectA[0], R*vectA[1])
plt.scatter(spanRx, spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %%
vectP = np.array([2,1])
vectQ = np.array([4,3])

R = np.arange (-10,10,1)

c1, c2 = np.meshgrid(R,R)

vectR = vectP + vectQ
spanRx = c1*vectP[0] + c2*vectQ[0]
spanRy = c1*vectP[1] + c2*vectQ[1]
##plt.scatter (R*vectP[0], R*vectQ[1])
##plt.scatter (R*vectP[0], R*vectQ[1])
plt.scatter(spanRx, spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# Take note that if vectors are seen to be as a 2-dimensional span we can say it has a Rank of 2 or $\mathbb{R}^2$. But if the span of the linear combination of vectors are seen to be like a line, they are said to be <b> linearly dependent </b> and they have a rank of 1 or $\mathbb{R}^1$.

# %% [markdown]
# # Activity
#
# ### Task 1
#
# Try different linear combinations using different scalar values. In your methodology discuss the different functions that you have used, the linear equation and vector form of the linear combination, and the flowchart for declaring and displaying linear combinations. Please make sure that your flowchart has only few words and not putting the entire code as it is bad practice. In your results, display and discuss the linear combination visualization you made. You should use the cells below for displaying the equation markdowns using LaTeX and your code.

# %% [markdown]
# #### Span of single vectors

# %% [markdown]
# $$C = \begin{bmatrix} 6\\8 \\\end{bmatrix} , V = \begin{bmatrix} 7\\4 \\\end{bmatrix} $$

# %%
vectC = np.array([6,8])
vectV = np.array([7,4])

# %% [markdown]
# $$C = f\cdot \begin{bmatrix} 6\\8 \\\end{bmatrix} $$

# %%
f = np.arange(-20,25,0.20)

plt.scatter(f*vectC[0],f*vectC[0])

plt.xlim(-25.5,25)
plt.ylim(-25.5,25)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# $$V = f\cdot \begin{bmatrix} 7\\4 \\\end{bmatrix} $$

# %%
f = np.arange(-18,27,0.25)

plt.scatter(f*vectV[0],f*vectV[1])

plt.xlim(-25,25)
plt.ylim(-25,25)
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![Ass10 (1).png](data:image/png;base64,...)

# %% [markdown]
# #### Span of linear combination of vectors

# %% [markdown]
# $$S = \begin{Bmatrix} f_1 \cdot\begin{bmatrix} 3\\7 \\\end{bmatrix},
# f_2 \cdot \begin{bmatrix} 2\\-4 \\\end{bmatrix}\end{Bmatrix} $$

# %%
vectE = np.array([3,7])
vectP= np.array([2,-4])

R = np.arange (-27,27,1.50)

f1, f2 = np.meshgrid(R,R)

vectR = vectE + vectP
spanRx = f1*vectE[0] + f2*vectP[0]
spanRy = f1*vectE[1] + f2*vectP[1]
##plt.scatter (R*vectE[0], R*vectP[1])
##plt.scatter (R*vectE[0], R*vectP[1])
plt.scatter(spanRx, spanRy, s=5, alpha=0.75)

plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.grid()
plt.show()

# %% [markdown]
# ![Ass10(2).png](data:image/png;base64,...)

# %% [markdown]
# ## Conclusion guide
#
# For your conclusion synthesize the concept and application of the laboratory. Briefly discuss what you have learn and achieved in this activity. At the end of your conclusion try to answer the question : "How can you apply the concept of linear combination in engineering or real-life situations?".
#
# In this laboratory activity, the students plotted their desired vectors into a 2-dimensional plane and try getting the output of the spans they’ve inputted. At the span of single vectors, we are to input the np.arange and plt.scatter but since it is a span of single vectors the expected output for this is a single line. On the other hand, the span of linear combination is the combination of where we can create a 2-dimensional system. This part of the laboratory is a bit tricky since there are a lot of codes we need to consider since there will be 2 linear combinations. In order for this part to be achieved, the students used the np.meshgrid for the rectangularity of the inputted arrays. The student tried different combination of codes to identify the purpose of each codes in Python.
#
#
# To answer the question “How can you apply the concept of linear combination
# in engineering or real-life situations?” As an engineer, we encounter physics as a subject which covers the speed, time and the distance of a specific object. Since these values can be either constant or it changes from time to time. On the other hand, this can also be used in any business especially this pandemic where people open small businesses, they can monitor the sales of their business just by inputting the sales or even budgeting the money they have. If you are familiar of the linear combination both of these situations can be used to see whether there is a change and compare the values in the graph.
